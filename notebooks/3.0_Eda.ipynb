# %% [markdown]
# <div style="text-align: center; background-color: #750E21; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   FINAL PROJECT: RESEARCHING ON MUSIC TASTE WORDWIDELY 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #0766AD; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 03 - Exploratory Data Analysis 📌
# </div>

# %% [markdown]
# ## **IMPORT LIBRARY** 🎄

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import textwrap
import ast

# %% [markdown]
# ## **EXPLORING DATA** 📝

# %% [markdown]
# <div style="text-align: left; font-family: 'Trebuchet MS', Arial, sans-serif; color: #FF90BC; padding: 20px; font-size: 28px; font-weight: bold; border-radius: 0 0 0 0">
#   STEP 1: Read cleaned data from processed folder 🔥
# </div>

# %%
cleaned_video_df = pd.read_csv('../data/processed/music_video_data.csv')
cleaned_video_df.head(10)
# Out:
#             Id                                          Song Name  \
# 0  9bZkp7q19f0                              Gangnam Style (강남스타일)
# 1  hT_nvWreIhg                                     Counting Stars
# 2  JGwWNGJdvx8                                       Shape of You
# 3  lp-EO5I60KA                                  Thinking out Loud
# 4  CevxZvSJLk8                                               Roar
# 5  kJQP7kiw5Fk                                          Despacito
# 6  FzG4uDgje3M                 Dame Tu Cosita (feat. Cutty Ranks)
# 7  pRpeEdMmmQ0  Waka Waka (This Time for Africa) [The Official...
# 8  fRh_vgS2dFE                                              Sorry
# 9  RgKAFK5djSk                 See You Again (feat. Charlie Puth)
#
#      Artist Name       Channel_name          View        Like  Subscriber  \
# 0            PSY        officialpsy  4.977100e+09  27830052.0  18400000.0
# 1    OneRepublic    OneRepublicVEVO  3.927344e+09  17491157.0   5470000.0
# ...

# %%
cleaned_audio_df = pd.read_csv('../data/processed/audio_features.csv')
cleaned_audio_df.head(10)
# Out:
#                spotify_id                                          song_name  \
# 0  03UrZgTINDqvnUMbbIMhql                              Gangnam Style (강남스타일)
# 1  2tpWsVSb9UEmDRxAl1zhX1                                     Counting Stars
# 2  7qiZfU4dY1lWllzX7mPBI3                                       Shape of You
# 3  34gCuhDGsG4bRPIf9bb02f                                  Thinking out Loud
# 4  6F5c58TMEs1byxUstkzVeM                                               Roar
# 5  6habFhsOp2NvshLv26DqMb                                          Despacito
# 6  09SNuR471zu5nVvC4IVG8j                 Dame Tu Cosita (feat. Cutty Ranks)
# 7  6bNB5gxFX6Q87DbQWb8OWZ  Waka Waka (This Time for Africa) [The Official...
# 8  09CtPGIpYB4BrO8qb1RGsF                                              Sorry
# 9  2JzZzZUQj3Qff7wapcbKjc                 See You Again (feat. Charlie Puth)
#
#      artist_name  popularity  duration_ms  danceability  energy  key  \
# ...

# %% [markdown]
# <div style="text-align: left; font-family: 'Trebuchet MS', Arial, sans-serif; color: #FF90BC; padding: 20px; font-size: 28px; font-weight: bold; border-radius: 0 0 0 0">
#   STEP 2: Numerical analysis using descriptive statistics 🔥
# </div>

# %% [markdown]
# Descriptive statistics show the characteristics of numerical features. It shows us the information such as:
# - The mean
# - The median
# - The mode
# - Quantiles (Quartiles, Percentiles, Deciles, Crocodiles?)
# - Range and IQR (Interquartile Range) (you might find that its relation to box plots)
# - Variance and Standard deviation (std dev)
# - Coefficient of Variation
# - Skewness
# - Kurtosis
# - Standard Error (of the sample mean)
# - Moments
# - Covariance and Correlation

# %%
df_copy_video = cleaned_video_df.select_dtypes(include='number')
pd.set_option('display.max_columns', None)
df_copy_video.describe()
# Out:
#                View          Like    Subscriber      Hashtag  \
# count  2.500000e+03  2.500000e+03  2.500000e+03  2500.000000
# mean   7.072674e+08  4.277323e+06  2.687815e+07     2.651600
# std    5.638744e+08  3.815576e+06  5.427648e+07     3.748258
# min    3.244410e+08  4.718660e+05  7.330000e+03     0.000000
# 25%    3.985463e+08  2.094270e+06  2.950000e+06     0.000000
# 50%    5.150177e+08  3.129072e+06  9.160000e+06     3.000000
# 75%    7.838052e+08  5.046277e+06  2.460000e+07     4.000000
# max    8.327580e+09  5.253674e+07  2.540000e+08    81.000000
#
#        Most view per day  Highest rank  Charted-duration  \
# count       2.500000e+03   2500.000000       2500.000000
# mean        3.776254e+06     36.487200         38.134000
# std         6.488007e+06     42.892043         52.068398
# min         1.413500e+05      1.000000          1.000000
# 25%         7.651115e+05      9.750000         17.000000
# 50%         1.837818e+06     21.000000         25.000000
# ...

# %%
df_copy_audio = cleaned_audio_df.select_dtypes(include='number')
pd.set_option('display.max_columns', None)
df_copy_audio.describe()
# Out:
#         popularity   duration_ms  danceability       energy          key  \
# count  2339.000000  2.339000e+03   2339.000000  2339.000000  2339.000000
# mean     65.223600  2.317336e+05      0.669306     0.691963     5.288585
# std      19.502671  7.868257e+04      0.144135     0.167752     3.608172
# min       0.000000  4.500000e+04      0.089900     0.021100     0.000000
# 25%      60.000000  1.956975e+05      0.580500     0.583500     2.000000
# 50%      71.000000  2.213410e+05      0.689000     0.711000     5.000000
# 75%      78.000000  2.522800e+05      0.775000     0.821000     8.000000
# max      98.000000  2.548912e+06      0.979000     0.998000    11.000000
#
#           loudness         mode  speechiness  acousticness  instrumentalness  \
# count  2339.000000  2339.000000  2339.000000   2339.000000       2339.000000
# mean     -5.774098     0.568619     0.092028      0.230615          0.023781
# std       2.557784     0.495375     0.083351      0.233323          0.125898
# ...

# %% [markdown]
# ### **OBSERVATION** 💬

# %% [markdown]
# - All the data statistics are stable and not meet any problems.

# %% [markdown]
# <div style="text-align: left; font-family: 'Trebuchet MS', Arial, sans-serif; color: #FF90BC; padding: 20px; font-size: 28px; font-weight: bold; border-radius: 0 0 0 0">
#   STEP 3: Describe the correlation between features in the dataset 🔥
# </div>

# %% [markdown]
# Considering the available features within the training dataset, we want to identify and analyse the relationships between them, and then determine which features within the dataset significantly contribute to our solution goal. By using calculation and visualisation, Python allows us to create a correlation matrix, which is a table that represents the correlation coefficients between different variables.

# %%
# Plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy_video.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %%
# Plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy_audio.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# ### **OBSERVATION** 💬

# %% [markdown]
# * At the first heatmap, there are some features that seem to have strong correlation with each other, namely `Like`, `View`, `Charted-duration`, `Most view per day`. Other features, in constrast, correlate quite weak.
# * In the second heatmap, the correlation is also quite weak among features. To have more information, we will continue to analyze in the following sections.

# %% [markdown]
# <div style="text-align: left; font-family: 'Trebuchet MS', Arial, sans-serif; color: #FF90BC; padding: 20px; font-size: 28px; font-weight: bold; border-radius: 0 0 0 0">
#   STEP 4: Coming to the QUESTION SECTION 🔥
# </div>

# %% [markdown]
# ## **Question 1** 🔔

# %% [markdown]
# After exploring the data, we have a better understanding of the data. Now let's see what questions can be answered with this data.
#
# ❓  **A possible question is:** Do videos with a higher popularity score on Spotify have a higher rank on YouTube?
#
# ✅  **Answering this question will** help us to predict the rank of a video if it is published on Youtube since most of the videos nowadays appear on Spotify first.
#
# 💡  **How we answer this question**: we will consider the `Popularity Score (Spotify)` and `Highest rank` of all music videos.

# %% [markdown]
# ### **Analyzing to get answer** 📝

# %% [markdown]
# **Step 01**:    Construct dataframe for `Popularity Score (Spotify)`

# %%
# Create dataframe for Popularity
popularity_df = cleaned_video_df[['Song Name', 'Popularity Score (Spotify)']]

# Sort the rows based of Popularity Score
popularity_df.sort_values('Popularity Score (Spotify)', inplace=True, ascending=False)

# Display
popularity_df.head(10)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2252\2364968087.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popularity_df.sort_values('Popularity Score (Spotify)', inplace=True, ascending=False)
#                             Song Name  Popularity Score (Spotify)
# 1435  All I Want for Christmas Is You                          97
# 651   All I Want for Christmas Is You                          97
# 859                         As It Was                          94
# 862                           Flowers                          93
# 691                   Sweater Weather                          93
# 560                    Last Christmas                          92
# 536                      Another Love                          92
# ...

# %%
plt.figure(figsize=(20, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=popularity_df.head(10), x="Song Name", y= "Popularity Score (Spotify)")

# %% [markdown]
# **Step 02**: Construct dataframe for `Highest rank`

# %%
# Create dataframe for Highest rank
rank_df = cleaned_video_df[['Song Name', 'Highest rank']]

# Sort the rows based of Highest rank
rank_df.sort_values('Highest rank', inplace=True, ascending=True)

# Display
rank_df.head(10)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2252\2876833822.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rank_df.sort_values('Highest rank', inplace=True, ascending=True)
#                   Song Name  Highest rank
# 0     Gangnam Style (강남스타일)           1.0
# 359           Hawái - Remix           1.0
# 381      Sexy And I Know It           1.0
# 386              Wide Awake           1.0
# 392         What's My Name?           1.0
# 393        Story of My Life           1.0
# 1493               Killshot           1.0
# 405                Memories           1.0
# 414       Que Tire Pa Lante           1.0
# 415           We Can't Stop           1.0

# %% [markdown]
# Since all of the top 10 Highest rank are all top 1, so we will take a look at the highest rank of top 10 `Popularity Score (Spotify)`

# %%
# Create dataframe for Highest rank
rank_df = cleaned_video_df[['Song Name', 'Highest rank']]

# Create a list of Song Name of Popularity Score
song_names = popularity_df['Song Name'].head(10).to_list()

# Extract song that are in top 10 of Popularity Score (Spotify)
rank_df = rank_df[rank_df['Song Name'].isin(song_names)]

# Sort the rows based of Popularity Score
rank_df.sort_values('Highest rank', inplace=True, ascending=True)

# Display rank
rank_df
# Out:
#                             Song Name  Highest rank
# 859                         As It Was           1.0
# 862                           Flowers           1.0
# 1435  All I Want for Christmas Is You           3.0
# 560                    Last Christmas           7.0
# 651   All I Want for Christmas Is You           7.0
# 2315                       CLASSY 101          16.0
# 691                   Sweater Weather          21.0
# 536                      Another Love          43.0
# 643                   Blinding Lights          44.0
# 400                            Yellow          98.0

# %%
# Create a horizontal bar chart
plt.barh(rank_df['Song Name'], rank_df['Highest rank'], color='skyblue')

# Set labels and title
plt.xlabel('Rank')
plt.ylabel('Song Name')
plt.title('Song Ranks')
# Out:
# Text(0.5, 1.0, 'Song Ranks')

# %% [markdown]
# ### **OBSERVATION** 💬
# - The Popularity Score on Spotify of the top 10 songs are not much different. All the scores are rated pretty high. All I Want for Christmas Is You being placed both 1st and 2nd so there's may be 2 versions of this song. The song with the lowest score in the top 10 is We Can't Stop but its score is still more than 90.
# - However, when it comes to rank on Youtube, some songs don't make it to top 1. The two songs that reached rank 1 on Youtube are Flowers and As It Was. Despite All I Want for Christmas Is You's high score on Spotify, its music video only make to rank 3 on Youtube. And even Yellow is ranked 98 on Youtbe which is quite low. Most of the songs that ranked top 1 don't appear on top 10 Popularity Score on Spotify too.
# - There are some explanations:
#     - Since singers usually release their music in albums and there is only 1 song is chosen as theme song, the other songs usually don't have an official music video on Youtube, they just have a lyric video so the rank of these songs on Youtube are usually not high.
#     - Since Youtube has a lot of kind of videos, if the singer is not famous enough, their music videos usually don't have a high rank.
#     - The number of people watching Youtube is problaly larger than that of Spotify so there are some songs that really famous on Youtube but people don't listen to them on Spotify much.
# - So we can conclude that if a song has a high popurality score on Spotify, that not means it has a high rank on Youtube.

# %% [markdown]
# ## **Question 2** 🔔

# %% [markdown]
# ❓  **A possible question is:** What kind of music genre is likely to have a high views on Youtube or have a high Popularity Score on Spotify.
#
# ✅  **Answering this question will** help us to know which music genre that people usually listen to. This can help the singers or composers easily to choose what music genre they should make in order to be famous.
#
# 💡  **How we answer this question**: we will consider the `Genre` of all music videos.

# %% [markdown]
# ### **Analyzing to get answer** 📝

# %% [markdown]
# **Step 01**: Split each genre into a seperate row

# %%
# Create new dataframe Genre
genre_df = pd.DataFrame()

# Taking out Genre column and convert its data type into list
genre_df['Genre'] = cleaned_video_df['Genre']
genre_df['Genre'] = genre_df['Genre'].str.split(',')
genre_df = genre_df.explode('Genre')

# %% [markdown]
# **Step 02**: Count for each genre

# %%
# Count occurrences of each genre
genre_counts = genre_df['Genre'].value_counts()
genre_counts

# Create dataframe
df = pd.DataFrame(genre_counts)
df
# Out:
#                             count
# Genre
#  pop                          496
#  urbano latino                319
#  trap latino                  266
# dance pop                     205
# pop                           194
# ...                           ...
#  tamil pop                      1
# new beat                        1
# miami bass                      1
#  musica popular colombiana      1
# modern country pop              1
#
# [734 rows x 1 columns]

# %% [markdown]
# **Step 03**: Visualization

# %%
# Plot the bar chart
ax = df.head(10).plot(kind='bar', legend=False, figsize=(10, 6))

# Customize the plot
ax.set_ylabel('Counts')
ax.set_xlabel('Genres')
ax.set_title('Counts of Genres')

# Show the plot
plt.show()

# %% [markdown]
# Let's see how many unique genres we have in our data

# %%
df[df['count'] == 1]
# Out:
#                             count
# Genre
# russian hip hop                 1
#  stomp and holler               1
#  pop teen brasileiro            1
#  indonesian pop rock            1
#  new jack swing                 1
# ...                           ...
#  tamil pop                      1
# new beat                        1
# miami bass                      1
#  musica popular colombiana      1
# modern country pop              1
#
# [251 rows x 1 columns]

# %% [markdown]
# The number of unique genres are pretty high, with 251 different kinds of genres.

# %% [markdown]
# ### **OBSERVATION** 💬
# - It can be seen that pop is the most popular genre with a approximately 700 songs are in pop. This number is much higher when compared with other kind of genres. It is double of counts for urbano latino which place 2nd after pop. There are also other kinds of pop including dance pop, latino pop and rap pop are in top 10.
# - The genres of our data are also diverse with total 596 kind of music genres.
# - Many kinds of latin music also appear in the top 10 such as: urbano latino, trap latino and latin pop.
# - There are other kinds of genre that are not pretty famous but this is also a unique ones since the music video using these kings of genre also well known.
# - In conclusion, if a singer want to choose a music genre that easily approach the audience, he or she should sing pop music.

# %% [markdown]
# ## **Question 3** 🔔

# %% [markdown]
# ❓  **A possible question is:** Who are the top artists based on the total number of views or likes and their average Popularity Score on Spotify.
#
# ✅  **Answering this question will** help the artists to know if their music videos are good enough to be published on Spotify.
#
# 💡  **How we answer this question**: we will consider the total `View` of each artist and count for average of `Popularity Score (Spotify)`.

# %% [markdown]
# ### **Analyzing to get answer** 📝

# %% [markdown]
# **Step 01**: Construct dataframe for total `View`

# %%
# Create new datafram for total view
view_df = pd.DataFrame()

# Count sum for each artist
view_df['Total View'] = cleaned_video_df.groupby('Artist Name')['View'].sum()

# Set the index as a column - artist
view_df['Artist Name'] = view_df.index

# Drop the index
view_df.reset_index(drop=True, inplace=True)

# Sort the rows based of Total View
view_df.sort_values('Total View', inplace=True, ascending=False)

# Display
top10_view = view_df.head(10)
top10_view
# Out:
#        Total View    Artist Name
# 472  2.248398e+10  Justin Bieber
# 283  2.147682e+10     Ed Sheeran
# 487  2.059260e+10     Katy Perry
# 109  1.790632e+10            BTS
# 875  1.788445e+10        Shakira
# 931  1.722485e+10   Taylor Swift
# 114  1.673724e+10      Bad Bunny
# 108  1.656974e+10      BLACKPINK
# 634  1.645473e+10       Maroon 5
# 298  1.638960e+10         Eminem

# %% [markdown]
# **Step 02**: Construct dataframe for average `Popularity Score (Spotify)`

# %%
# Create new datafram for Popularity Score
avg_popularity_df = pd.DataFrame()

# Count sum for each artist
avg_popularity_df['Avg Score'] = cleaned_video_df.groupby('Artist Name')['Popularity Score (Spotify)'].mean()

# Set the index as a column - artist
avg_popularity_df['Artist Name'] = avg_popularity_df.index

# Drop the index
avg_popularity_df.reset_index(drop=True, inplace=True)

# Sort the rows based of Total View
avg_popularity_df.sort_values('Avg Score', inplace=True, ascending=False)

# Display
avg_popularity_df.head(10)
# Out:
#       Avg Score                   Artist Name
# 953        93.0             The Neighbourhood
# 1035       90.0                     Yng Lvcas
# 812        90.0                          Rema
# 1058       90.0                          a-ha
# 356        90.0                 Glass Animals
# 76         90.0                Arctic Monkeys
# 794        89.0                     Radiohead
# 955        89.0                    The Police
# 217        88.0  Creedence Clearwater Revival
# 950        88.0                   The Killers

# %% [markdown]
# **Step 03**: Extract top 10 views artists from `Popularity Score (Spotify)` dataframe

# %%
# Create list for artist names
artist_names = view_df.head(10)['Artist Name']

# Extract artist from Popularity Score dataframe
top10_score = avg_popularity_df[avg_popularity_df['Artist Name'].isin(artist_names)]
top10_score
# Out:
#      Avg Score    Artist Name
# 931  81.200000   Taylor Swift
# 283  78.882353     Ed Sheeran
# 114  78.120000      Bad Bunny
# 298  77.705882         Eminem
# 472  74.913043  Justin Bieber
# 487  72.875000     Katy Perry
# 875  72.133333        Shakira
# 109  71.238095            BTS
# 634  70.785714       Maroon 5
# 108  66.352941      BLACKPINK

# %% [markdown]
# **Step 04**: Visualization

# %%
# Merge the two datasets on 'Artist Name'
df_combined = pd.merge(top10_view, top10_score, on='Artist Name')

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(15, 6))

# Bar graph for Total Views on the primary y-axis
ax1.bar(df_combined['Artist Name'], df_combined['Total View'], color='cyan', label='Total Views')
ax1.set_xlabel('Artist Name')
ax1.set_ylabel('Total Views', color='blue')
ax1.tick_params('y', colors='blue')
ax1.legend(loc='upper left')

# Create a secondary y-axis
ax2 = ax1.twinx()

# Line graph for Average Score on the secondary y-axis
ax2.plot(df_combined['Artist Name'], df_combined['Avg Score'], marker='o', color='red', label='Average Score')
ax2.set_ylabel('Average Score', color='red')
ax2.tick_params('y', colors='red')
ax2.legend(loc='upper right')

plt.title('Total Views and Average Score by Artist')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **OBSERVATION** 💬
# - Justin Bieber has the highest total views among the artists, followed by Ed Sheeran and Taylor Swift.
# - On the other hand, although Taylor Swift is only placed 6th based on total views, she has the highest popularity score on Spotify.
# - It can be seen that music groups don't have a high popularity score on Spotify. This is easy to understand since they focus on their music video more, their products not only focus on music but also focus on video and visual.
# - Singers seem to have a better score on spotify, their score are all above 70.
# - So we can conclude that to have a good score on Spotify, singers will perform better than groups and their music video on Youtube don't have to have a high views.

# %% [markdown]
# ## **Question 4** 🔔

# %% [markdown]
# ❓  **A possible question is:** What time frames do artists like to publish videos at, and does each time frame have any effect on the number of views on YouTube of that video?
#
# ✅  **Answering this question will** help artists consider time frames that help increase views, or avoid time frames that can compete with many other artists.
#
# 💡  **How we answer this question**: A day will be divided into 12 time frames. We will consider the `Publish_time`, average of `View` of each video publishing and classify them into 12 time frames.

# %% [markdown]
# ### **Analyzing to get answer** 📝

# %% [markdown]
# **Step 01**: Construct dataframe and statistics on the number of videos posted on each time frame and the corresponding average views

# %%
publish_hour_df = cleaned_video_df.loc[:, ['View', 'Publish_time']]
cleaned_video_df
publish_hour_df['Publish_time'] = pd.to_datetime(cleaned_video_df['Publish_time']).dt.hour
publish_hour_res = publish_hour_df.groupby('Publish_time', as_index=False)['View'].mean()

publish_hour_List = []

for i in range(0, 24): 
    publish_hour = publish_hour_df[publish_hour_df['Publish_time'] == i]['Publish_time'].count()
    publish_hour_List.append(publish_hour)
print(publish_hour_List)
publish_hour_res['Quantity'] = publish_hour_List

publish_hour_res
# Out:
# [103, 69, 58, 60, 226, 154, 76, 166, 119, 66, 57, 67, 94, 101, 130, 128, 159, 99, 78, 82, 91, 77, 125, 106]
#     Publish_time          View  Quantity
# 0            0.0  7.247424e+08       103
# 1            1.0  6.982082e+08        69
# 2            2.0  6.201109e+08        58
# 3            3.0  8.412711e+08        60
# 4            4.0  7.362589e+08       226
# 5            5.0  6.970476e+08       154
# 6            6.0  6.142144e+08        76
# 7            7.0  7.624319e+08       166
# 8            8.0  6.865256e+08       119
# 9            9.0  7.121574e+08        66
# 10          10.0  7.640027e+08        57
# 11          11.0  7.715592e+08        67
# 12          12.0  6.110672e+08        94
# 13          13.0  6.308267e+08       101
# 14          14.0  7.145190e+08       130
# 15          15.0  7.075092e+08       128
# 16          16.0  7.017868e+08       159
# 17          17.0  6.590737e+08        99
# 18          18.0  6.774397e+08        78
# ...

# %% [markdown]
# **Step 02**: Sort data in ascending/descending `Quantity` and `View` fields according to time frame.

# %%
publish_hour_res.sort_values(by=['Quantity'], ascending=False).head(3)
# Out:
#     Publish_time          View  Quantity
# 4            4.0  7.362589e+08       226
# 7            7.0  7.624319e+08       166
# 16          16.0  7.017868e+08       159

# %%
publish_hour_res.sort_values(by=['Quantity'], ascending=True).head(3)
# Out:
#     Publish_time          View  Quantity
# 10          10.0  7.640027e+08        57
# 2            2.0  6.201109e+08        58
# 3            3.0  8.412711e+08        60

# %%
publish_hour_res.sort_values(by=['View'], ascending=False).head(3)
# Out:
#     Publish_time          View  Quantity
# 3            3.0  8.412711e+08        60
# 22          22.0  7.891624e+08       125
# 11          11.0  7.715592e+08        67

# %%
publish_hour_res.sort_values(by=['View'], ascending=True).head(3)
# Out:
#     Publish_time          View  Quantity
# 12          12.0  6.110672e+08        94
# 6            6.0  6.142144e+08        76
# 2            2.0  6.201109e+08        58

# %% [markdown]
# **Step 03**: Visualization

# %%
# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(15, 6))

# Bar graph for Quantity on the primary y-axis
ax1.bar(publish_hour_res['Publish_time'], publish_hour_res['Quantity'], color='green', label='Quantity')
ax1.set_xlabel('Publish_time')
ax1.set_ylabel('Quantity', color='blue')
ax1.tick_params('y', colors='green')
ax1.legend(loc='upper left')

# Create a secondary y-axis
ax2 = ax1.twinx()

# Line graph for Average View on the secondary y-axis
ax2.plot(publish_hour_res['Publish_time'], publish_hour_res['View'], marker='o', color='red', label='Average View')
ax2.set_ylabel('Average View', color='red')
ax2.tick_params('y', colors='red')
ax2.legend(loc='upper right')

plt.title('Total Views and Average View of Youtue videos')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **OBSERVATION** 💬
# - It shows that Videos with high views often publish videos during the hours of 4 AM, 7 AM and 4 PM; not often publish videos during the hours of 10 AM, 2 AM and 3 AM.
# - At the same time, video views are higher at publishing time frames such as 3 AM, 10 PM and 11 AM; are lower at publishing time frames such as 12 AM, 6 AM and 2 AM
# - From there, it shows that the time to publish videos before 8 AM is often fluctuating, more unpredictable than after 2 PM (depending on factors such as videos having international markets in many different time zones, so it is not is actually affected by local time).
# - Conclusion: Video publishing time is often the initial influencing factor, and does not have a large impact on the video's final view count. However, care must also be taken to achieve the necessary initial interaction for videos that depend heavily on the domestic market.

# %% [markdown]
# ## **Question 5** 🔔

# %% [markdown]
# ❓  **A possible question is:** Which country has the largest YouTube video publishing market with views? Over the years, has that influence fluctuated?
#
# ✅  **Answering this question will** help artists choose the market to develop their YouTube videos in the long term and sustainably.
#
# 💡  **How we answer this question**: the data will sort by year. after that, it will create a comparison between before and after x year to see the change in the rate of videos reaching the top of countries in the youtube video media race.

# %% [markdown]
# ### **Analyzing to get answer** 📝

# %% [markdown]
# **Step 01**: Construct dataframe and statistics on the number of videos posted on each time frame and the corresponding average views

# %%
# Construct new dataframe have 'View', 'Country' and 'Publish_time' data fields, sort by Publish_time
country_ration_df = cleaned_video_df.loc[:, ['View', 'Country', 'Publish_time']].sort_values(by=['Publish_time'], ascending=True)[:2491]
country_ration_df['Publish_time'] = pd.to_datetime(country_ration_df['Publish_time']).dt.year

# Split into 2 dataframes which are 2 time periods so that there are equal number of videos reaching the top
country_ration_df_1 = country_ration_df.loc[:].sort_values(by=['Publish_time'], ascending=True)[:int(len(country_ration_df) / 2)]

country_ration_df_2 = country_ration_df.loc[:].sort_values(by=['Publish_time'], ascending=True)[int(len(country_ration_df) / 2):]

chosen_year = country_ration_df_2['Publish_time'].head(1)
print(chosen_year)

# Quantity to count number of videos posted by each country
country_ration_df_1['Quantity'] = 0
country_ration_df_2['Quantity'] = 0
# Out:
# 1967    2016
# Name: Publish_time, dtype: int32

# %% [markdown]
# **Step 02**: Find top 10 YouTube video publishing countries before and after 2016

# %%
temp_1 = country_ration_df_1.groupby('Country', as_index=False)['Quantity'].count().sort_values(by=['Quantity'], ascending=False)
temp_1.head(10)
# Out:
#    Country  Quantity
# 25      US       287
# 12      IN        75
# 11      GB        30
# 2       BR        24
# 20      PR        16
# 5       DE        11
# 17      MX        11
# 23      TH         9
# 15      KR         9
# 18      NL         7

# %%
temp_2 = country_ration_df_2.groupby('Country', as_index=False)['Quantity'].count().sort_values(by=['Quantity'], ascending=False)
color_set = [(0.8853517877739331, 0.3190311418685121, 0.29042675893886966), (0.9873125720876587, 0.6473663975394078, 0.3642445213379469), (0.9971549404075356, 0.9118031526336025, 0.6010765090349866), (0.9288735101883892, 0.9715494040753557, 0.6380622837370243), 
(0.6334486735870821, 0.8521337946943485, 0.6436755094194541), (0.2800461361014994, 0.6269896193771626, 0.7024221453287197), (0.8853517877739331, 0.3190311418685121, 0.29042675893886966), (0.9873125720876587, 0.6473663975394078, 0.3642445213379469), 
(0.9971549404075356, 0.9118031526336025, 0.6010765090349866), (0.9288735101883892, 0.9715494040753557, 0.6380622837370243), (0.6334486735870821, 0.8521337946943485, 0.6436755094194541), (0.2800461361014994, 0.6269896193771626, 0.7024221453287197),
(0.8853517877739331, 0.3190311418685121, 0.29042675893886966), (0.9873125720876587, 0.6473663975394078, 0.3642445213379469), (0.9971549404075356, 0.9118031526336025, 0.6010765090349866), (0.9288735101883892, 0.9715494040753557, 0.6380622837370243), 
(0.6334486735870821, 0.8521337946943485, 0.6436755094194541), (0.2800461361014994, 0.6269896193771626, 0.7024221453287197), (0.8853517877739331, 0.3190311418685121, 0.29042675893886966), (0.9873125720876587, 0.6473663975394078, 0.3642445213379469), 
(0.9971549404075356, 0.9118031526336025, 0.6010765090349866), (0.9288735101883892, 0.9715494040753557, 0.6380622837370243), (0.6334486735870821, 0.8521337946943485, 0.6436755094194541), (0.2800461361014994, 0.6269896193771626, 0.7024221453287197),
(0.8853517877739331, 0.3190311418685121, 0.29042675893886966), (0.9873125720876587, 0.6473663975394078, 0.3642445213379469), (0.9971549404075356, 0.9118031526336025, 0.6010765090349866), (0.9288735101883892, 0.9715494040753557, 0.6380622837370243), 
(0.6334486735870821, 0.8521337946943485, 0.6436755094194541), (0.2800461361014994, 0.6269896193771626, 0.7024221453287197), (0.8853517877739331, 0.3190311418685121, 0.29042675893886966), (0.9873125720876587, 0.6473663975394078, 0.3642445213379469), 
(0.9971549404075356, 0.9118031526336025, 0.6010765090349866), (0.9288735101883892, 0.9715494040753557, 0.6380622837370243), (0.6334486735870821, 0.8521337946943485, 0.6436755094194541), (0.2800461361014994, 0.6269896193771626, 0.7024221453287197), (0.8853517877739331, 0.3190311418685121, 0.29042675893886966)]

temp_2['Color_code'] = color_set
temp_1 = pd.merge(temp_1, temp_2[['Country', 'Color_code']])

temp_2[['Country', 'Quantity']].head(10)
# Out:
#    Country  Quantity
# 34      US       245
# 16      IN       225
# 5       BR        96
# 27      PR        73
# 19      KR        38
# 8       CO        32
# 2       AR        18
# 22      MX        16
# 30      TH        16
# 14      GB        16

# %% [markdown]
# **Step 03**: Visualization

# %%
import matplotlib.pyplot as plt

# Sample data for the first pie chart
categories1 = temp_1['Country']
percentage_distribution1 = temp_1['Quantity']

# Sample data for the second pie chart
categories2 = temp_2['Country']
percentage_distribution2 = temp_2['Quantity']

# Creating subplots with one row and two columns
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plotting the first pie chart
axs[0].pie(percentage_distribution1, startangle=90, colors=temp_1['Color_code'])
axs[0].set_title('Video ratio of countries before 2016')

# Plotting the second pie chart
axs[1].pie(percentage_distribution2, startangle=90, colors=temp_2['Color_code'])
axs[1].set_title('Video ratio of countries after 2016')

total_1 = sum(percentage_distribution1)
first_legend = plt.legend(
    title = 'Before 2016',
    loc='lower left',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total_1) * 100) for l, s in zip(categories1, percentage_distribution1)],
    prop={'size': 8},
    bbox_to_anchor=(0.0, 1),
    bbox_transform=fig.transFigure
)
ax = plt.gca().add_artist(first_legend)

total_2 = sum(percentage_distribution2)
second_legend = plt.legend(
    title = 'After 2016',
    loc='lower right',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total_2) * 100) for l, s in zip(categories2, percentage_distribution2)],
    prop={'size': 8},
    bbox_to_anchor=(0.0, 1),
    bbox_transform=fig.transFigure
)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Display the pie charts
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2252\39878907.py:47: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### **OBSERVATION** 💬
#
# - Top 5 before 2016: US	(287), IN (75), GB (30), BR (24), PR (16)
# - Top 5 after 2016: US (245), IN (225), BR (96), PR (73), KR (38)
# - We see that the US (United States) still maintains its leading position, but has decreased from 287 to 245, and the rate also decreased sharply from 55.1% to 28.5%.
# - Meanwhile, this rate is shared with many other countries, most notably IN (India) increased from 75 to 225, with a sharp increase from 14.4% to 26.2% (over 1/4).
# - At the same time, there is the highlight of KR (South Korea) whose population size is not too high but has a remarkable increase from 9 to 38, the rate increased from 1.7% to 4.4%.
# - In short, although the US market today is leading and stable, it no longer holds a unique position, but shares it with many other emerging markets (such as India, Korea, Brazil,...). At that time, opportunities will come to many people around the world, not just Americans who can dominate the rankings.

# %% [markdown]
# ## **QUESTION 6** 🔔

# %% [markdown]
# ❓  **A possible question is:** How the feature `Most View Per Day` values distribute across different genres ?
#
# ✅  **Answering this question will** give us insights into the audience'a taste on different taste of music, which could give new artists approaches on forming a particular music style in the long run for both musical values and financial income.
#
# 💡  **How we answer this question**: We intend to categorize the genre first, then list out all the songs belong to each genre and take out their mean *most view per day*. Consequently, plot on with histogram for visualization with answer to the question.

# %% [markdown]
# ### **Analyzing to get answer** 📝

# %%
genre_df = cleaned_video_df.copy()
genre_df = genre_df.assign(genre=genre_df['Genre'].str.split(',')).explode('genre')
genre_df.drop(columns=['Genre'], inplace=True)

genre_statistic = genre_df.groupby('genre').agg({'Most view per day': 'mean'}, as_index=False).sort_values(by='Most view per day', ascending=False)
genre_statistic.reset_index(inplace=True)
#set full width
pd.set_option('display.max_colwidth', None)
genre_statistic.head(10)
# Out:
#                   genre  Most view per day
# 0   indonesian pop rock         40383151.0
# 1             uzbek pop         34956961.0
# 2       russian hip hop         34956961.0
# 3          russian trap         34956961.0
# 4      estonian hip hop         34956961.0
# 5         ambient lo-fi         32522894.0
# 6            dance rock         31982536.0
# 7                grunge         26132100.0
# 8            supergroup         26132100.0
# 9               nyc rap         26106850.0

# %%
lower_quantile = genre_statistic['Most view per day'].quantile(0.25)
upper_quantile = genre_statistic['Most view per day'].quantile(0.75)
median = genre_statistic['Most view per day'].median()

print('Lower quantile: ', lower_quantile)
print('Upper quantile: ', upper_quantile)
print('Median: ', median)
# Out:
# Lower quantile:  1216227.0
# Upper quantile:  4016236.0089285714
# Median:  2508129.2142857146

# %%
genre_statistic_tail = genre_statistic.tail(20)
genre_statistic_head = genre_statistic.head(20)

# Create a figure and axis
fig, axs = plt.subplots(2, 1, figsize=(20, 15))

axs[0].bar(genre_statistic_head['genre'], genre_statistic_head['Most view per day'], color='skyblue', label='Most view per day', width=0.5)
axs[0].set_xticklabels(genre_statistic_head['genre'], rotation=45, ha='right', fontsize=15)
axs[0].set_xlabel('Genre', labelpad=20, fontsize=18)
axs[0].set_ylabel('Most view per day', labelpad=20, fontsize=18)
axs[0].set_title('Top 20 genres with highest average views per day', pad=20, fontsize=20, fontweight='bold')

axs[1].bar(genre_statistic_tail['genre'], genre_statistic_tail['Most view per day'], color='skyblue', label='Most view per day', width=0.5)
axs[1].set_xticklabels(genre_statistic_tail['genre'], rotation=45, ha='right', fontsize=15)
axs[1].set_xlabel('Genre', labelpad=20, fontsize=18)
axs[1].set_ylabel('Most view per day', labelpad=20, fontsize=18)
axs[1].set_title('Top 20 genres with lowest average views per day', pad=20, fontsize=20, fontweight='bold')

# show the lower and upper quantile line on 2 graphs
axs[0].axhline(y=lower_quantile, color='red', linestyle='--', linewidth = 3)
axs[0].axhline(y=upper_quantile, color='blue', linestyle='--', linewidth = 3)
axs[0].axhline(y=median, color='green', linestyle='--', linewidth = 3)

axs[1].axhline(y=lower_quantile, color='red', linestyle='--', linewidth = 3)
axs[1].axhline(y=upper_quantile, color='blue', linestyle='--', linewidth = 3)
axs[1].axhline(y=median, color='green', linestyle='--', linewidth = 3)

plt.legend(['Lower Quantile', 'Upper Quantile', 'Median'], loc='upper right')

plt.tight_layout()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2252\3548633242.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0].set_xticklabels(genre_statistic_head['genre'], rotation=45, ha='right', fontsize=15)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2252\3548633242.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1].set_xticklabels(genre_statistic_tail['genre'], rotation=45, ha='right', fontsize=15)

# %% [markdown]
# ### **OBSERVATION** 💬
#
# * In term of *Top 20 genres with most average views per day*, we observe that **Indonesia pop rock** achieve the highest average views per day about 40 million view in a day. The next four genres in top seem to share the same amount of average views per day, namely **uzbek pop**, **russian hip hop**, **rusian trap** and **estonian hip hop**, roughly 35 million views. A fast glance at those 5 genres, it is quite clearly that 5 top genres mainly root in those areas that are densely populated with a great passion for music. Therefore, those artists who locate in those areas that have a high population density, instead making those musical works that heads forward international style, could delve into the culture of their own country as well. This would create a better chance of achieving success as gaining support from a huge amount of local fans; or else there would be possibility that you can't success in any market: locally or internationally.
# * Besides that, we also feel that in this chart, music of kinds like **rap**, **rock** or **hip hop** also receive great love from audiences.
# * Those top genres with most average views per days truly outweight the index of `upper quantile`, which is only around 4 million views.
# * About *Top 20 genres with least average views per day*, those genres of music are all below 500,000 views; quite low in comparison with the whole sample. Actually, those genres are quite strange in the music market; usually have name of a particular country in it (in other words, `global spectrum`). These low average views per day for these genres may indicate less mainstream appeal, suggesting that these genres head for perhaps smaller audiences with some criteria in regional popularity or cultural influences.

# %% [markdown]
# ## **QUESTION 7** 🔔

# %% [markdown]
# ❓  **A possible question is:** Is there correlation between the duration of a song `Duration` and its popularity score on Spotify `Popularity Score (Spotify)` ?
#
# ✅  **Answering this question will** give us insights into the duration of a song that has influence on its popularity score on Spotify.
#
# 💡  **How we answer this question**: We intend to get 2 columns `Duration` and `Popularity Score (Spotify)`; then calculate its `correlation coefficient` and plot on graph for deeper insight.

# %% [markdown]
# ### **Analyzing to get answer** 📝

# %% [markdown]
# **Step 1**: Get out 2 columns need taking insight.

# %%
#correlation analysis
duration_popularity_df = cleaned_video_df[['Duration', 'Popularity Score (Spotify)']]
duration_popularity_df.head(10)
# Out:
#   Duration  Popularity Score (Spotify)
# 0  0:04:13                          75
# 1  0:04:44                          88
# 2  0:04:24                          88
# 3  0:04:57                          85
# 4  0:04:30                          74
# 5  0:04:42                          81
# 6  0:02:33                          39
# 7  0:03:31                          69
# 8  0:03:26                          85
# 9  0:03:58                          61

# %% [markdown]
# **Step 2**: Check for its information. And we saw that there exist null value in the column `Duration`, then drop it for better analyzation.

# %%
duration_popularity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 2 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Duration                    2491 non-null   object
#  1   Popularity Score (Spotify)  2500 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 39.2+ KB

# %%
#Drop rows with null values
duration_popularity_df.dropna(inplace=True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2252\2252228632.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duration_popularity_df.dropna(inplace=True)

# %% [markdown]
# **Step 3**: Change the column `Duration` to `datetime` type and then turn it into second.

# %%
# Change the data type of Duration to datetime
duration_popularity_df['Duration'] = pd.to_datetime(duration_popularity_df['Duration'], format='%H:%M:%S')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2252\1788169022.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duration_popularity_df['Duration'] = pd.to_datetime(duration_popularity_df['Duration'], format='%H:%M:%S')

# %%
# Convert the Duration to seconds (Datetime: datetime64[ns] -> int64)
duration_popularity_df['Duration'] = duration_popularity_df['Duration'].dt.hour * 3600 + duration_popularity_df['Duration'].dt.minute * 60 + duration_popularity_df['Duration'].dt.second
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2252\2153363147.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duration_popularity_df['Duration'] = duration_popularity_df['Duration'].dt.hour * 3600 + duration_popularity_df['Duration'].dt.minute * 60 + duration_popularity_df['Duration'].dt.second

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(15, 10))

ax.scatter(duration_popularity_df['Duration'], duration_popularity_df['Popularity Score (Spotify)'], s=duration_popularity_df['Popularity Score (Spotify)'] * 10, color='skyblue')
ax.scatter(duration_popularity_df['Duration'], duration_popularity_df['Popularity Score (Spotify)'], color='skyblue')
ax.set_xlabel('Duration (seconds)', labelpad=20, fontsize=18, fontfamily='monospace')
ax.set_ylabel('Popularity Score (Spotify)', labelpad=20, fontsize=18, fontfamily='monospace')
ax.set_title('Duration vs Popularity Score (Spotify)', pad=20, fontsize=22, fontweight='bold', fontfamily='monospace', color='green')
# Out:
# Text(0.5, 1.0, 'Duration vs Popularity Score (Spotify)')

# %% [markdown]
# ### **OBSERVATION** 💬
# - From the plot figure, we found that most of spots gather near the Origin `O`.
# - There exists some outliers. Some songs that has `Duration` > 2000 (seconds) all have `Popularity Score (Spotify)` quite low, below 20 points out of 100.
# - From this, we could draw a conclusion that people usually don't have much interest in any songs that take for too long. People prefer song with shorter duration, mostly under 1000 seconds. We will analize more deeper in the following part.

# %%
# Remove outliers
duration_popularity_df = duration_popularity_df[duration_popularity_df['Duration'] < 1000]
duration_popularity_df = duration_popularity_df[duration_popularity_df['Popularity Score (Spotify)'] < 100]

# Plot the scatter plot
fig, ax = plt.subplots(figsize=(15, 10))

ax.scatter(duration_popularity_df['Duration'], duration_popularity_df['Popularity Score (Spotify)'], s=duration_popularity_df['Popularity Score (Spotify)'] * 10, color='SlateBlue', alpha=0.5)

# Set the labels and title
ax.set_xlabel('Duration (seconds)', color='SlateBlue', fontsize=15, labelpad=20, fontfamily= 'monospace')
ax.set_ylabel('Popularity Score (Spotify)', color='SlateBlue', fontsize=15, labelpad=20, fontfamily= 'monospace')
ax.set_title('Popularity Score (Spotify) by Duration', fontsize=18, fontweight='bold', fontfamily= 'monospace', color='green', loc='center', pad=20, rotation=0, wrap=True)

# draw the regression line
z = np.polyfit(duration_popularity_df['Duration'], duration_popularity_df['Popularity Score (Spotify)'], 1)
p = np.poly1d(z)
plt.plot(duration_popularity_df['Duration'], p(duration_popularity_df['Duration']), color='red', linewidth=3)

# draw the correlation coefficient
corr = duration_popularity_df['Duration'].corr(duration_popularity_df['Popularity Score (Spotify)'])
plt.text(650, 90, 'Correlation coefficient: ' + str(round(corr, 2)), fontsize=14, fontweight='bold', fontfamily= 'monospace', color='red')

# circle the dense area
plt.axvspan(0, 500, facecolor='g', alpha=0.1)
plt.axvspan(500, 1000, facecolor='y', alpha=0.1)

# set the x-axis scale
plt.xlim(0, 1000)
# set the y-axis scale
plt.ylim(0, 100)


rect = plt.Rectangle((150, 45), 250, 48, fill=False, color='orange', linewidth=2, linestyle='--')
ax.add_patch(rect)

# %% [markdown]
# ### **OBSERVATION** 💬
#
# * `Corellation coefficient` calculated is about `-0.04`, which means `Popularity Score (Spotify)` and `Duration (seconds)` have negative correlation. In other words, if `Popularity Score (Spoitfy)` is getting higher, then the `Duration (seconds)` should be shortened.
# * This characteristic is also shown in a more visualizable way with the *linear regression line*. This line is going down from right to left, but not too steep.
# * In this plot graph, we have removed all those outliers, and just concentrating on those songs that durate below 1000 seconds. We can see that most singers and producers publish short- time songs, about 190 seconds to below 400 seconds. Although being in the same area of song duration, the score could vary widely; from very low (under 20 points) to nearly max score (100 points), mainly going from 50 points to 90 points.
# * In conclusion, those features tell us a truth that not the duration decide the success of a song, but it will someway come from the real quality that producers put in the music works. However, If artists want to ensure their success, they firstly meet the prerequisite that the duration of a song should not be over 10 minutes (> 600 seconds).
