# %% [markdown]
# <div style="text-align: center; background-color: #750E21; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   FINAL PROJECT: RESEARCHING ON MUSIC TASTE WORLDWIDELY 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #0766AD; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 00 - INTRODUCTION 📌
# </div>

# %% [markdown]
# ## Group introduction

# %% [markdown]
# - Course: Introduction to Data Science
# - Class: 21KHDL2
# - Semester: 1/23-24
# - Group ID: 8
# - Group member:
#     - Nguyễn Văn Đăng Huỳnh (Student ID: 21127063; Email: nvdhuynh21@clc.fitus.edu.vn)
#     - Trần Hiếu Tâm (Student ID: 21127423; Email: thtam21@clc.fitus.edu.vn)
#     - Nguyễn Thị Minh Minh (Student ID: 21127528; Email: ntmminh21@clc.fitus.edu.vn)
# - Duration: 16/11/2023 to 14/12/2023

# %% [markdown]
# ## Project introduction

# %% [markdown]
# This is a project officially called "Researching on music taste worldwide", carried out from November to December 2023 at the Faculty of Information Technology, University of Science, VNU-HCM.
#
# Currently, digital media in general and music in cyberspace in particular are developing very strongly, creating a digital community where people can easily share and get rich from it. According to statistics from Youtube, their Total videos reach Over 800 million videos (2023), with Total users reaching 2.70 billion of 100+ countries worldwide (2023), bringing the platform's revenue in 2022 to 29.24 billion USD (2022).
#
# At the same time, according to Spotify's statistics, their Total songs reach Over 100 million songs (2023), with Total users reaching 551 million of 184 countries worldwide (2023), and have revenue in 2022 reaching 12.33 billion USD (2022). .
# Through our project, the team aims to understand and provide accurate analysis of the market and today's music listening tastes of the world's netizens. From there, there are appropriate suggestions for authors in the process of publishing their works, creating many development opportunities for everyone with ability.
#
# Information is taken from sources Kworb.net, Youtube.com and Spotify.com. We took a list of the top 2,500 videos with the highest views on Youtube, from which we have a basis to analyze and learn valuable experiences from the above videos.
# The above project will still have many shortcomings. Therefore, we look forward to receiving everyone's candid comments to help our project be more objective, accurate and effective.

# %% [markdown]
# ## Brief of Project

# %% [markdown]
# - Data source(s):
#     1. Kworb.net;
#     2. Youtube.com;
#     3. Spotify.com.
# - Get top 2500 most view video from Youtube. Additional data from Kworb.net and Spotify.com.
# - Steps-to-do: Data collection -> Data pre-processing and exploration -> Data modeling
# - Data exploration: We created and answered 7/7 question in this project.
# - [Data modeling] problem: Based on some features of a song such as `danceability`, `energy`, `loudness`,... predict `Popularity Score on Spotify`.
# - [Data modeling] Chosen features for modelling: [1]`danceability`; [2]`energy`; [3]`key`; [4]`loudness`; [5]`mode`; [6]`speechiness`; [7]`acousticness`; [8]`instrumentalness`; [9]`liveness`; [10]`valence`; [11]`tempo`; [12]`duration_ms`; [13]`time_signature`; [14]`Popularity Score (Spotify)`
# - [Data modeling] Chosen metric for modelling: RMSE (Root Mean Squared Error)
# - [Data modeling] Split data: TRAINING (70%), VALIDATION (15%), AND TESTING (15%) SETS
# - [Data modeling] model(s):
#     1. Linear Regression;
#     2. Polynomial Regression;
#     3. Neural Network.

# %% [markdown]
# ## Plan

# %% [markdown]
# **List of tool(s):**
# - GitHub: The group's common workspace, used to effectively manage the entire source code of the project. Follow detailed at here (https://github.com/danghuynh-bit/youtube_project_DS)
# - Trello: The group's common workspace, used to assign work, manage and evaluate the level of completion. Follow detailed at here (https://trello.com/b/GvZXYaQX/youtube-project-ds)
#
# **List of Tasks**
# - ![image.png](attachment:image.png)
# - ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Contact information

# %% [markdown]
# If you have any project-related concerns, please feel free to address them by composing an email and sending it to a member of our team for valuable response
# - 21127063 - Nguyễn Văn Đăng Huỳnh (nvdhuynh21@clc.fitus.edu.vn)
# - 21127423 - Trần Hiếu Tâm (thtam21@clc.fitus.edu.vn)
# - 21127528 - Nguyễn Thị Minh Minh (ntmminh21@clc.fitus.edu.vn)
#
# Faculty of Information Technology, VNUHCM - University of Science
#
# Addr: 227 Nguyen Van Cu Str., Ward 4, District 5, Ho Chi Minh City
